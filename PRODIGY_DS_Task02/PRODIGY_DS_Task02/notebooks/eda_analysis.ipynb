# %% [markdown]
# # PRODIGY DS Task-02 – Titanic EDA
# Data cleaning and exploratory data analysis on the Titanic dataset.

# %%
import sys
sys.path.insert(0, '../source_code')
from eda import load_and_clean, get_summary_stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df, cleaning_log = load_and_clean('../dataset/titanic.csv')
print('Shape:', df.shape)
df.head()

# %% [markdown]
# ## Cleaning Log

# %%
for step in cleaning_log:
    print(f"\n[{step['step']}]\n  {step['detail']}")

# %% [markdown]
# ## Summary Statistics

# %%
stats = get_summary_stats(df)
for k,v in stats.items():
    print(f'{k}: {v}')

# %% [markdown]
# ## Survival by Gender

# %%
from eda import chart_survival_by_gender, chart_age_distribution, chart_pclass_analysis, chart_correlation_heatmap, chart_family_embark
import base64, io
from IPython.display import Image

def show(b64):
    return Image(data=base64.b64decode(b64))

show(chart_survival_by_gender(df))

# %%
show(chart_age_distribution(df))

# %%
show(chart_pclass_analysis(df))

# %%
show(chart_correlation_heatmap(df))

# %%
show(chart_family_embark(df))
